# %%
from tetratopic import MOF_tetra
import numpy as np
template = 'she.cif' #lib file 
node_connection= 6   #lib file 

templates_dir = 'template_database' #default 
nodes_dir = 'nodes' #default 
edges_dir = 'edges' #default 
new_mof = MOF_tetra(templates_dir,nodes_dir,edges_dir,template,node_connection)
new_mof.load(False)
# Out:
# =========================================================================================================
# template : she.cif
# =========================================================================================================
#
# Number of vertices =  20
# Number of edges =  48
#
# *****************************************************************
# RMSD of the compatible node BBs with assigned vertices:
# *****************************************************************
#
# vertex Er (6 connected)
#      6c_Zr_1_Ch.cif deviation = 0.35973 (within tolerance)
#      6c_Al_1.cif deviation = 0.64872 (outside tolerance)
#      MIL-53.cif deviation = 0.59159 (outside tolerance)
#      6c_Al_1_Ch.cif deviation = 0.63493 (outside tolerance)
# * 1 compatible building blocks out of 4 available for node Er *
# vertex V (4 connected)
#      4c_tetracenter_porphyrin_Ch.cif deviation = 0.00381 (within tolerance)
# * 1 compatible building blocks out of 1 available for node V *
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# vertex assignment :  ['v1-4c_tetracenter_porphyrin_Ch.cif', 'v2-6c_Zr_1_Ch.cif']
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# edge assignment :  ('1B_2F_Ch.cif',)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# scaling unit cell and vertex positions...
# optimizing with local minimization algorithm L-BFGS-B...
#
# The final objective function value is 164512.325
#
# *******************************************
# The scaled unit cell parameters are :
# *******************************************
# a    : 37.79517
# b    : 37.66227
# c    : 37.67012
# alpha: 90.01194
# beta : 86.80152
# gamma: 86.76161
# <class 'networkx.utils.decorators.argmap'> compilation 30:3: FutureWarning:
#
# shortest_path will return an iterator that yields
# (node, path) pairs instead of a dictionary when source
# and target are unspecified beginning in version 3.5
#
# To keep the current behavior, use:
#
# 	dict(nx.shortest_path(G))

# %%
supercell= np.asarray([0,0,0])
new_mof.basic_supercell(supercell)
new_mof.write_basic_supercell('41.gro','42.xyz')
# Out:
# <div id="3dmolviewer_17299606810176551"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17299606810176551" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17299606810176551 = null;
# var warn = document.getElementById("3dmolwarning_17299606810176551");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17299606810176551 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17299606810176551"),{backgroundColor:"white"});
# viewer_17299606810176551.zoomTo();
# 	viewer_17299606810176551.addModelsAsFrames("generated by MOF_BUILD\n74\n    1EDG     N1    1   2.979   3.911   1.297\n    1EDG     N2    2   3.191   3.914   1.098\n    1EDG     N3    3   3.007   3.916   0.872\n    1EDG     N4    4   2.795   3.913   1.072\n    1EDG     C5    5   3.089   3.911   1.379\n    1EDG     C6    6   2.860   3.910   1.364\n    1EDG     C7    7   3.126   3.917   0.800\n    1EDG     C8    8   2.899   3.916   0.785\n    1EDG     C9    9   3.264   3.913   1.207\n    1EDG    C10   10   3.281   3.915   0.992\n    1EDG    C11   11   2.709   3.912   1.170\n    1EDG    C12   12   2.720   3.914   0.955\n    1EDG    C13   13   3.032   3.909   1.514\n    1EDG    C14   14   2.898   3.909   1.505\n    1EDG    C15   15   3.091   3.918   0.667\n    1EDG    C16   16   2.951   3.918   0.657\n    1EDG    C17   17   3.409   3.914   1.182\n    1EDG    C18   18   3.414   3.915   1.050\n    1ED
= $3Dmol.createViewer(document.getElementById("3dmolviewer_1729960681018677"),{backgroundColor:"white"});
# viewer_1729960681018677.zoomTo();
# 	viewer_1729960681018677.addModelsAsFrames("generated by MOF_BUILD\n3050\n    2NOD    Zr1    1   2.247  -0.200   1.644\n    2NOD     O2    2   2.423  -0.297   1.711\n    2NOD     O3    3   2.283  -0.122   1.438\n    2NOD     O4    4   2.266  -0.387   1.523\n    2NOD     O5    5   2.335   0.107   1.803\n    2NOD     O6    6   2.070  -0.488   1.530\n    2NOD     O7    7   2.413  -0.055   1.676\n    2NOD     O8    8   2.101  -0.013   1.378\n    2NOD     O9    9   2.054  -0.214   1.561\n    2NOD    O10   10   2.141  -0.018   1.651\n    2NOD    O11   11   2.121  -0.331   1.751\n    2NOD    O12   12   2.208  -0.135   1.841\n    2NOD   Zr13   13   1.810  -0.104   1.858\n    2NOD   Zr14   14   1.935  -0.361   1.655\n    2NOD   Zr15   15   2.121   0.057   1.847\n    2NOD   Zr16   16   1.957  -0.027   1.549\n    2NOD    O17   17   2.220   0.076   2.033\n    2NOD    O18   18   1.855  -0.108   1.381\n    2NOD    O19   19   1.936   0.027   1.751\n    2NOD    O20   20   1.849  -0.169   1.661\n    2NOD    O21   21   1.916  -0.286   1.851\n    2NOD    O22   22   2.003  -0.090   1.941\n    2NOD    C23   23   2.213  -0.056   1.364\n    2NOD    C24   24   2.418   0.049   1.738\n    2NOD    C25   25   2.186  -0.474   1.497\n    2NOD    O26   26   1.830  -0.384   1.473\n    2NOD    O27   27   1.722  -0.411   1.699\n    2NOD    O28   28   1.643  -0.250   1.826\n    2NOD    C29   29   1.638  -0.353   1.764\n    2NOD    O30   30   2.293  -0.364   1.966\n    2NOD   Zr31   31   2.100  -0.277   1.953\n    2NOD    O32   32   1.774  -0.183   2.064\n    2NOD    O33   33   1.925  -0.554   1.743\n    2NOD    O34   34   2.059  -0.483   1.981\n    2NOD    O35   35   2.206  -0.207   2.124\n    2NOD    O36   36   1.956  -0.291   2.124\n    2NOD    C37   37   1.844  -0.248   2.138\n    2NOD    O38   38   1.638   0.006   1.800\n    2NOD    O39   39   2.114   0.254   1.769\n    2NOD    O40   40   1.791   0.083   1.979\n    2NOD    O41   41   1.987   0.184   1.973\n    2NOD    O42   42   1.991   0.179   1.515\n    2NOD    O43   43   1.779   0.086   1.533\n    2NOD    C44   44   1.871   0.170   2.005\n    2NOD    H45   45   2.193   0.050   1.603\n    2NOD    H46   46   1.762  -0.175   1.615\n    2NOD    H47   47   1.994  -0.060   2.034\n    2NOD    H48   48   2.166  -0.418   1.754\n    2NOD    H49   49   1.846  -0.033   1.317\n    2NOD    H50   50   1.882  -0.611   1.675\n    2NOD    H51   51   2.076  -0.502   2.077\n    2NOD    H52   52   1.972   0.195   1.419\n    2NOD    H53   53   2.163   0.310   1.835\n    2NOD    H54   54   2.241   0.172   2.042\n    2NOD    H55   55   2.201  -0.280   2.191\n    2NOD    H56   56   1.704   0.023   1.517\n    2NOD    H57   57   1.671   0.093   1.766\n    2NOD    H58   58   2.482  -0.303   1.632\n    2NOD    H59   59   2.292  -0.432   2.038\n    2NOD    H60   60   2.171   0.256   1.688\n    2NOD    H61   61   1.601  -0.038   1.719\n    2NOD    H62   62   1.897  -0.388   1.400\n    2NOD    H63   63   1.919  -0.170   1.337\n    2NOD    H64   64   2.153  -0.135   2.165\n    2NOD    H65   65   2.017  -0.588   1.749\n    2NOD    H66   66   2.399  -0.391   1.731\n    3NOD    Zr1   67   2.248   1.609   0.149\n    3NOD     O2   68   2.427   1.689   0.069\n    3NOD     O3   69   2.291   1.529   0.353\n    3NOD     O4   70   2.291   1.794   0.267\n    3NOD     O5   71   2.299   1.294  -0.011\n    3NOD     O6   72   2.104   1.911   0.272\n    3NOD     O7   73   2.399   1.449   0.109\n    3NOD     O8   74   2.105   1.437   0.427\n    3NOD     O9   75   2.063   1.640   0.245\n    3NOD    O10   76   2.127   1.436   0.152\n    3NOD    O11   77   2.126   1.749   0.050\n    3NOD    O12   78   2.190   1.546  -0.043\n    3NOD   Zr13   79   1.791   1.548  -0.033\n    3NOD   Zr14   80   1.951   1.795   0.157\n    3NOD   Zr15   81   2.088   1.361  -0.041\n    3NOD   Zr16   82   1.952   1.462   0.266\n    3NOD    O17   83   2.172   1.333  -0.233\n    3NOD    O18   84   1.869   1.553   0.439\n    3NOD    O19   85   1.913   1.408   0.066\n    3NOD    O20  ...

# %%
#scalar parameter to adjust boundary 
new_mof.basic_supercell(supercell,scalar=0.05,boundary_scalar=0.16)
new_mof.write_basic_supercell('43.gro','44.xyz')
# Out:
# <div id="3dmolviewer_17299606817390761"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17299606817390761" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_17299606817390761 = null;
# var warn = document.getElementById("3dmolwarning_17299606817390761");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17299606817390761 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17299606817390761"),{backgroundColor:"white"});
# viewer_17299606817390761.zoomTo();
# 	viewer_17299606817390761.addModelsAsFrames("generated by MOF_BUILD\n74\n    1EDG     N1    1   2.979   3.911   1.297\n    1EDG     N2    2   3.191   3.914   1.098\n    1EDG     N3    3   3.007   3.916   0.872\n    1EDG     N4    4   2.795   3.913   1.072\n    1EDG     C5    5   3.089   3.911   1.379\n    1EDG     C6    6   2.860   3.910   1.364\n    1EDG     C7    7   3.126   3.917   0.800\n    1EDG     C8    8   2.899   3.916   0.785\n    1EDG     C9    9   3.264   3.913   1.207\n    1EDG    C10   10   3.281   3.915   0.992\n    1EDG    C11   11   2.709   3.912   1.170\n    1EDG    C12   12   2.720   3.914   0.955\n    1EDG    C13   13   3.032   3.909   1.514\n    1EDG    C14   14   2.898   3.909   1.505\n    1EDG    C15   15   3.091   3.918   0.667\n    1EDG    C16   16   2.951   3.918   0.657\n    1EDG    C17   17   3.409   3.914   1.182\n    1EDG    C18   18   3.414   3.915   1.050\n    1EDG    C19   19   2.568   3.912   1.127\n    1EDG    C20   20   2.581   3.913   0.995\n    1EDG    C21   21   3.220   3.912   1.350\n    1EDG    C22   22   2.734   3.910   1.318\n    1EDG    C23   23   2.761   3.915   0.826\n    1EDG    C24   24   3.258   3.917   0.859\n    1EDG    H25   25   3.087   3.908   1.606\n    1EDG    H26   26   2.832   3.908   1.590\n    1ED
# 	viewer_1729960681740727.addModelsAsFrames("generated by MOF_BUILD\n3703\n    2NOD    Zr1    1   2.247  -0.200   1.644\n    2NOD     O2    2   2.423  -0.297   1.711\n    2NOD     O3    3   2.283  -0.122   1.438\n    2NOD     O4    4   2.266  -0.387   1.523\n    2NOD     O5    5   2.335   0.107   1.803\n    2NOD     O6    6   2.070  -0.488   1.530\n    2NOD     O7    7   2.413  -0.055   1.676\n    2NOD     O8    8   2.101  -0.013   1.378\n    2NOD     O9    9   2.054  -0.214   1.561\n    2NOD    O10   10   2.141  -0.018   1.651\n    2NOD    O11   11   2.121  -0.331   1.751\n    2NOD    O12   12   2.208  -0.135   1.841\n    2NOD   Zr13   13   1.810  -0.104   1.858\n    2NOD   Zr14   14   1.935  -0.361   1.655\n    2NOD   Zr15   15   2.121   0.057   1.847\n    2NOD   Zr16   16   1.957  -0.027   1.549\n    2NOD    O17   17   2.220   0.076   2.033\n    2NOD    O18   18   1.855  -0.108   1.381\n    2NOD    O19   19   1.936   0.027   1.751\n    2NOD    O20   20   1.849  -0.169   1.661\n    2NOD    O21   21   1.916  -0.286   1.851\n    2NOD    O22   22   2.003  -0.090   1.941\n    2NOD    C23   23   2.213  -0.056   1.364\n    2NOD    C24   24   2.418   0.049   1.738\n    2NOD    C25   25   2.186  -0.474   1.497\n    2NOD    O26   26   1.830  -0.384   1.473\n    2NOD    O27   27   1.722  -0.411   1.699\n    2NOD    O28   28   1.643  -0.250   1.826\n    2NOD    C29   29   1.638  -0.353   1.764\n    2NOD    O30   30   2.293  -0.364   1.966\n    2NOD   Zr31   31   2.100  -0.277   1.953\n    2NOD    O32   32   1.774  -0.183   2.064\n    2NOD    O33   33   1.925  -0.554   1.743\n    2NOD    O34   34   2.059  -0.483   1.981\n    2NOD    O35   35   2.206  -0.207   2.124\n    2NOD    O36   36   1.956  -0.291   2.124\n    2NOD    C37   37   1.844  -0.248   2.138\n    2NOD    O38   38   1.638   0.006   1.800\n    2NOD    O39   39   2.114   0.254   1.769\n    2NOD    O40   40   1.791   0.083   1.979\n    2NOD    O41   41   1.987   0.184   1.973\n    2NOD    O42   42   1.991   0.179   1.515\n    2NOD    O43   43   1.779   0.086   1.533\n    2NOD    C44   44   1.871   0.170   2.005\n    2NOD    H45   45   2.193   0.050   1.603\n    2NOD    H46   46   1.762  -0.175   1.615\n    2NOD    H47   47   1.994  -0.060   2.034\n    2NOD    H48   48   2.166  -0.418   1.754\n    2NOD    H49   49   1.846  -0.033   1.317\n    2NOD    H50   50   1.882  -0.611   1.675\n    2NOD    H51   51   2.076  -0.502   2.077\n    2NOD    H52   52   1.972   0.195   1.419\n    2NOD    H53   53   2.163   0.310   1.835\n    2NOD    H54   54   2.241   0.172   2.042\n    2NOD    H55   55   2.201  -0.280   2.191\n    2NOD    H56   56   1.704   0.023   1.517\n    2NOD    H57   57   1.671   0.093   1.766\n    2NOD    H58   58   2.482  -0.303   1.632\n    2NOD    H59   59   2.292  -0.432   2.038\n    2NOD    H60   60   2.171   0.256   1.688\n    2NOD    H61   61   1.601  -0.038   1.719\n    2NOD    H62   62   1.897  -0.388   1.400\n    2NOD    H63   63   1.919  -0.170   1.337\n    2NOD    H64   64   2.153  -0.135   2.165\n    2NOD    H65   65   2.017  -0.588   1.749\n    2NOD    H66   66   2.399  -0.391   1.731\n    3NOD    Zr1   67   2.248   1.609   0.149\n    3NOD     O2   68   2.427   1.689   0.069\n    3NOD     O3   69   2.291   1.529   0.353\n    3NOD     O4   70   2.291   1.794   0.267\n    3NOD     O5   71   2.299   1.294  -0.011\n    3NOD     O6   72   2.104   1.911   0.272\n    3NOD     O7   73   2.399   1.449   0.109\n    3NOD     O8   74   2.105   1.437   0.427\n    3NOD     O9   75   2.063   1.640   0.245\n    3NOD    O10   76   2.127   1.436   0.152\n    3NOD    O11   77   2.126   1.749   0.050\n    3NOD    O12   78   2.190   1.546  -0.043\n    3NOD   Zr13   79   1.791   1.548  -0.033\n    3NOD   Zr14   80   1.951   1.795   0.157\n    3NOD   Zr15   81   2.088   1.361  -0.041\n    3NOD   Zr16   82   1.952   1.462   0.266\n    3NOD    O17   83   2.172   1.333  -0.233\n    3NOD    O18   84   1.869   1.553   0.439\n    3NOD    O19   85   1.913   1.408   0.066\n    3NOD    O20  ...

# %%
new_mof.defect_missing([1,2,3],[1,2,3])
new_mof.term_defective_model()
new_mof.write_tntemof('45.gro')
# Out:
# this MOF has 1 fragment
# UNsaturated edges(linkers) exist, need linker_termination <= 7
# UNsaturated nodes exist, <=23 nodes need node_termination
# degree of edge E3 is 3, neighbor nodes are [2, 14, 17]
# degree of edge E4 is 3, neighbor nodes are [2, 13, 16]
# degree of edge E5 is 3, neighbor nodes are [3, 9, 20]
# degree of edge E7 is 3, neighbor nodes are [2, 15, 23]
# degree of edge E10 is 3, neighbor nodes are [3, 9, 23]
# degree of edge E11 is 3, neighbor nodes are [4, 7, 16]
# degree of edge E15 is 3, neighbor nodes are [5, 6, 17]
# <div id="3dmolviewer_1729960682051272"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1729960682051272" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_1729960682051272 = null;
# var warn = document.getElementById("3dmolwarning_1729960682051272");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1729960682051272 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1729960682051272"),{backgroundColor:"white"});
# viewer_1729960682051272.zoomTo();
# 	viewer_1729960682051272.addModelsAsFrames("generated by MOF_BUILD\n3004\n    1NOD    Zr1    1   0.648   1.655   1.716\n    1NOD     O2    2   0.823   1.579   1.623\n    1NOD     O9    3   0.460   1.747   1.699\n    1NOD    O10    4   0.539   1.654   1.896\n    1NOD    O11    5   0.519   1.554   1.584\n    1NOD    O12    6   0.598   1.461   1.782\n    1NOD   Zr13    7   0.199   1.464   1.805\n    1NOD   Zr14    8   0.340   1.659   1.550\n    1NOD   Zr15    9   0.508   1.460   1.972\n    1NOD   Zr16   10   0.360   1.766   1.884\n    1NOD    O17   11   0.597   1.270   1.993\n    1NOD    O18   12   0.268   1.938   1.800\n    1NOD    O19   13   0.328   1.565   1.938\n    1NOD    O20   14   0.250   1.658   1.740\n    1NOD    O21   15   0.309   1.465   1.626\n    1NOD    O22   16   0.388   1.372   1.823\n    1NOD    O26   17   0.244   1.846   1.525\n    1NOD    O30   18   0.681   1.330   1.555\n    1NOD   Zr31   19   0.487   1.353   1.638\n    1NOD    O33   20   0.329   1.571   1.357\n    1NOD    O34   21   0.450   1.326   1.432\n    1NOD    O35   22   0.583   1.178   1.710\n    1NOD    O38   23   0.028   1.531   1.912\n    1NOD    O39   24   0.501   1.539   2.169\n    1NOD    O42   25   0.392   1.799   2.090\n    1NOD    O43   26   0.181   1.791   1.993\n    1NOD    H45   27   0.592   1.700   1.965\n    1NOD    H46   28   0.165   1.709   1.733\n    1NOD    H47   29   0.374   1.279   1.854\n    1NOD    H48   30   0.567   1.549   1.497\n    1NOD    H49   31   0.261   2.003   1.874\n    1NOD    H50   32   0.290   1.640   1.299\n    1NOD    H51   33   0.462   1.230   1.413\n    1NOD    H52   34   0.378   1.896   2.106\n    1NOD    H53   35   0.545   1.471   2.226\n    1NOD    H54   36   0.615   1.260   2.090\n    1NOD    H55   37   0.577   1.111   1.637\n    1NOD    H56   38   0.108   1.810   1.929\n    1NOD    H57   39   0.062   1.563   2.000\n    1NOD    H58   40   0.886   1.655   1.618\n    1NOD    H59   41   0.678   1.258   1.487\n    1NOD    H60   42   0.562   1.617   2.171\n    1NOD    H61   43  -0.004   1.613   1.867\n    1NOD    H62   44   0.314   1.915   1.522\n    1NOD    H63   45   0.335   1.978   1.739\n    1NOD    H64   46   0.527   1.140   1.782\n    1NOD    H65   47   0.421   1.560   1.324\n    1NOD    H66   48   0.799   1.560   1.529\n    2NOD    Zr1   49   2.104   1.693   2.035\n    2NOD     O2   50   1.923   1.608   1.963\n    2NOD     O9   51   2.294   1.665   2.121\n    2NOD    O10   52   2.222   1.867   2.032\n    2NOD    O11   53   2.224   1.555   1.930\n    2NOD    O12   54   2.152   1.757   1.840\n    2NOD   Zr13   55   2.551   1.762   1.831\n    2NOD   Zr14   56   2.405   1.512   2.029\n    2NOD   Zr15   57   2.251   1.943   1.837\n    2NOD   Zr16   58   2.403   1.845   2.138\n    2NOD    O17   59   2.157   1.970   1.650\n    2NOD    O18   60   2.496   1.756   2.307\n    2NOD    O19   61   2.431   1.900   1.937\n    2NOD    O20   62   2.504   1.698   2.026\n    2NOD    O21   63   2.433   1.587   1.834\n    2NOD    O22   64   2.361   1.789   1.745\n    2NOD    O26   65   2.505   1.481   2.213\n    2NOD    O30   66   2.055   1.535   1.710\n    2NOD   Zr31   67   2.253   1.609   1.728\n    2NOD    O33   68   2.404   1.320   1.939\n    2NOD    O34   69   2.280   1.402   1.699\n    2NOD    O35   70   2.155   1.687   1.556\n    2NOD    O38   71   2.729   1.860   1.894\n    2NOD    O39   72   2.269   2.138   1.918\n    2NOD    O42   73   2.382   2.053   2.174\n    2NOD    O43   74   2.588   1.946   2.159\n    2NOD    H45   75   2.173   1.938   2.079\n    2NOD    H46   76   2.589   1.686   2.074\n    2NOD    H47   77   2.374   1.820   1.652\n    2NOD    H48   78   2.173   1.471   1.925\n    2NOD    H49   79   2.508   1.830   2.372\n    2NOD    H50   80   2.442   1.259   2.007\n    2NOD    H51   81   2.264   1.384   1.602\n    2NOD    H52   82   2.400   2.067   2.270\n    2NOD    H53   83   2.226   2.198   1.852\n    2NOD    H54   84   2.143   2.067   1.641\n    2NOD    H55   85   2.157   1.615   1.488\n    2NOD    H56  ...

# %%
#SUB
